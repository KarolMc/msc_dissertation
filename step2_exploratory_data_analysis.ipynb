# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolMc/msc_dissertation/blob/main/step2_exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import os

import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

# %%
nhanes_data = pd.read_csv('/content/drive/MyDrive/NHANES/merged_csv/merged_selected_lab_data.csv')

# %%
nhanes_data.shape
# Out:
# (50588, 228)

# %%
nhanes_data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1     SEQN  SDDSRVYR  RIDSTATR  RIDEXMON  RIDAGEYR  \
# 0           0             0  41475.0       5.0       2.0       2.0      62.0
# 1           1             1  41476.0       5.0       2.0       1.0       6.0
# 2           2             2  41477.0       5.0       2.0       2.0      71.0
# 3           3             3  41478.0       5.0       2.0       2.0       1.0
# 4           4             4  41479.0       5.0       2.0       1.0      52.0
#
#    RIDAGEMN  RIDAGEEX  RIDRETH1  ...  LBXSF4SI  LBDSF4LC  LBXSF5SI  LBDSF5LC  \
# 0     751.0     752.0       5.0  ...       NaN       NaN       NaN       NaN
# 1      81.0      82.0       5.0  ...       NaN       NaN       NaN       NaN
# 2     859.0     860.0       3.0  ...       NaN       NaN       NaN       NaN
# 3      17.0      17.0       3.0  ...       NaN       NaN       NaN       NaN
# 4     629.0     630.0       1.0  ...       NaN       NaN       NaN       NaN
#
# ...

# %%
nhanes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50825 entries, 0 to 50824
# Columns: 875 entries, Unnamed: 0 to LBDINLC
# dtypes: float64(874), int64(1)
# memory usage: 339.3 MB

# %%
nhanes_data = nhanes_data.drop(['Unnamed: 0', 'Unnamed: 0.1', 'SDDSRVYR', 'RIDEXMON', 'DMDYRSUS', 'SIALANG','SIAPROXY', 'SIAINTRP', 'FIALANG', 'FIAPROXY', 'FIAINTRP', 'MIALANG', 'MIAPROXY', 'MIAINTRP', 'WTINT2YR', 'WTMEC2YR','SDMVPSU', 'SDMVSTRA'], axis = 1)

# %%
nhanes_data.head()
# Out:
#       SEQN  RIDSTATR  RIDAGEYR  RIDAGEMN  RIDAGEEX  RIDRETH1  DMDBORN2  \
# 0  41475.0       2.0      62.0     751.0     752.0       5.0       1.0
# 1  41476.0       2.0       6.0      81.0      82.0       5.0       1.0
# 2  41477.0       2.0      71.0     859.0     860.0       3.0       1.0
# 3  41478.0       2.0       1.0      17.0      17.0       3.0       1.0
# 4  41479.0       2.0      52.0     629.0     630.0       1.0       2.0
#
#    DMDCITZN  DMDEDUC3  DMDEDUC2  ...  LBXSF4SI  LBDSF4LC  LBXSF5SI  LBDSF5LC  \
# 0       1.0       NaN       3.0  ...       NaN       NaN       NaN       NaN
# 1       1.0       0.0       NaN  ...       NaN       NaN       NaN       NaN
# 2       1.0       NaN       3.0  ...       NaN       NaN       NaN       NaN
# 3       1.0       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       1.0       NaN       1.0  ...       NaN       NaN       NaN       NaN
#
#    LBXSF6SI  LBDSF6LC  Served_Military  No_military_service  Male  Female
# ...

# %%
nhanes_data['SEQN'] = nhanes_data['SEQN'].astype('int')

# %%
nhanes_data.head()
# Out:
#     SEQN  RIDSTATR  RIDAGEYR  RIDAGEMN  RIDAGEEX  RIDRETH1  DMDBORN2  \
# 0  41475       2.0      62.0     751.0     752.0       5.0       1.0
# 1  41476       2.0       6.0      81.0      82.0       5.0       1.0
# 2  41477       2.0      71.0     859.0     860.0       3.0       1.0
# 3  41478       2.0       1.0      17.0      17.0       3.0       1.0
# 4  41479       2.0      52.0     629.0     630.0       1.0       2.0
#
#    DMDCITZN  DMDEDUC3  DMDEDUC2  ...  LBXSF4SI  LBDSF4LC  LBXSF5SI  LBDSF5LC  \
# 0       1.0       NaN       3.0  ...       NaN       NaN       NaN       NaN
# 1       1.0       0.0       NaN  ...       NaN       NaN       NaN       NaN
# 2       1.0       NaN       3.0  ...       NaN       NaN       NaN       NaN
# 3       1.0       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       1.0       NaN       1.0  ...       NaN       NaN       NaN       NaN
#
#    LBXSF6SI  LBDSF6LC  Served_Military  No_military_service  Male  Female
# ...

# %%
# nhanes_data.rename(columns=
                  #  {"RIDSTATR": "Int Status", 
                  #   "RIAGENDR": "Gender", 
                  #   "RIDAGEYR": "Age_yrs", 
                  #   "RIDAGEMN": "Age_months",
                  #   "RIDAGEEX": "Age_months_at_exam",
                  #   "RIDRETH1": "Race_ethnicity", 
                  #   "DMQMILIT": "Military_service", 
                  #   "DMDBORN2	": "country_birth", 
                  #   "DMDEDUC3": "education_years_under19",
                  #   "DMDEDUC2": "education_level_adult",
                  #   "DMDMARTL": "marital_status", 
                  #   "DMDHHSIZ": "total_people_in_house", 
                  #   "INDHHIN2": "household_income", 
                  #   "INDFMPIR": "fam_income_poverty_ratio",
                  #   "RIDEXPRG": "pregnant",})

# %%
# plot count plot for the gender column
sns.countplot(nhanes_data['Male'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.violinplot(data=nhanes_data, x='Male', y="RIDAGEYR", inner="quart", linewidth=1)
sns.despine(left=True)

# %%
def diabetes_check(row):
  if row['LBXGH'] >= 6.5 or row['LBXGLU'] >= 126 or row['LBXGLT'] >= 200:
    return 'Diabetic on one or more tests'
  elif (row['LBXGH'] >= 5.7 and row['LBXGH'] <6.5) or (row['LBXGLU'] >= 100 and row['LBXGLU'] < 126) or (row['LBXGLT'] >= 140 and row['LBXGLT'] < 200):
    return 'Prediabetes on one or more tests' 
  else:
    return 'Normal'

# %%
nhanes_data['Diabetes_check'] = nhanes_data.apply(lambda row : diabetes_check(row), axis=1)

# %%
nhanes_data['Diabetes_check'].value_counts()
# Out:
# Normal                              35562
# Prediabetes on one or more tests    10939
# Diabetic on one or more tests        4087
# Name: Diabetes_check, dtype: int64

# %%
col_list = ['Male','RIDAGEYR','DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'INDHHIN2', "INDFMPIR", 'Diabetes_check']

df = nhanes_data[col_list]

# %%
sns.set_theme(style="ticks")


sns.pairplot(data=df, hue='Diabetes_check')
